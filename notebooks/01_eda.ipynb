# %% [markdown]
# # 📊 Exploratory Data Analysis
#
# This notebook explores the synthetic sales data to understand patterns, seasonality, and relationships.

# %%
# Import required libraries
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from datetime import date, timedelta

# Import ForecastIt modules
from forecastit.data.make_synthetic import generate_synthetic_data
from forecastit.config.settings import Settings
